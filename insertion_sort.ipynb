# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanraj3010/algorithms-lab/blob/main/insertion_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def insertionSort(arr):

    for i in range(1, len(arr)):
        key = arr[i]

        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j = j - 1
        arr[j + 1] = key


arr = []
n = int(input("Enter number of elements: "))
for i in range(0, n):
    element = int(input("Enter element: "))
    arr.append(element)

insertionSort(arr)

print("Sorted array is:")
for i in range(len(arr)):
    print(arr[i], end=" ")
print()

import matplotlib.pyplot as plt

x = [2, 3, 4, 5, 6, 7, 8, 9, 10]
y = [0.0001, 0.0003, 0.0005, 0.0007, 0.0009, 0.0011, 0.0013, 0.0015, 0.0017]
plt.plot(x, y)
plt.xlabel('Size of array')
plt.ylabel('Time (seconds)')
plt.title('Time Complexity of Insertion Sort')
plt.show()
# Out:
# Enter number of elements: 5
# Enter element: 6
# Enter element: 9
# Enter element: 10
# Enter element: 88
# Enter element: 43
# Sorted array is:
# 6 9 10 43 88
